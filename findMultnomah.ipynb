# %%
import pandas as pd
import os

# %%
df = pd.read_excel('housing.xlsx')

# %%
df.columns = df.iloc[3]
df.head(20)
# Out:
# 3  NaN                                            COUNTY
# 0  NaN                                                NaN  \
# 1  NaN  OREGON HOUSING AND COMMUNITY SERVICES AFFORDAB...
# 2  NaN                                                NaN
# 3  NaN                                            COUNTY
# 4  NaN                                                NaN
# 5  NaN                                             Baker
# 6  NaN                                                NaN
# 7  NaN                                             Baker
# 8  NaN                                                NaN
# 9  NaN                                             Baker
# 10 NaN                                                NaN
# 11 NaN                                             Baker
# 12 NaN                                                NaN
# 13 NaN                                             Baker
# 14 NaN                                                NaN
# ...

# %%
df = df.dropna(axis=1, how='all')
df = df.dropna(how='all')
df.head(20)
# Out:
# 3                                             COUNTY
# 1   OREGON HOUSING AND COMMUNITY SERVICES AFFORDAB...  \
# 3                                             COUNTY
# 5                                              Baker
# 7                                              Baker
# 9                                              Baker
# 11                                             Baker
# 13                                             Baker
# 15                                             Baker
# 17                                             Baker
# 19                                             Baker
# 21                                             Baker
# 23                                             Baker
# 25                                            Benton
# 27                                            Benton
# 29                                            Benton
# 31                                            Benton
# 33                                            Benton
# ...

# %%
mask = df['COUNTY '] == 'Multnomah '
df_mult = df.loc[mask]
df_mult.head(10)
# Out:
# 3    NaN     COUNTY            PROJECT NAME    CYCLE
# 1816 NaN  Multnomah   10th Avenue Townhomes    2000S   \
# 1818 NaN  Multnomah      1200 Building, The    2011A
# 1820 NaN  Multnomah             124th & Ash   2018L3
# 1822 NaN  Multnomah        12th Ave Terrace    1992P
# 1824 NaN  Multnomah       146th East & West    2020A
# 1826 NaN  Multnomah          148th Ave Apts   2021-2
# 1828 NaN  Multnomah                72Foster    2017A
# 1830 NaN  Multnomah      85 Stories Group 1    2014A
# 1832 NaN  Multnomah      85 Stories Group 2    2014A
# 1834 NaN  Multnomah      85 Stories Group 5    2018A
#
# 3               PROJECT ADDRESS  PROJ CITY
# 1816  4916-38 NE 10th Ave; 4616   Portland   \
# 1818               1220 SW 12th   Portland
# 1820            12370 SE Ash St   Portland
# 1822        1515-29 SW 12th Ave   Portland
# 1824   14603 & 14525 E Burnside   Portland
# 1826           208 SE 148th Ave   Portland
# 1828           5005 SE 72nd Ave   Portland
# ...

# %%
df_mult = df_mult.reset_index(drop=True)
df_mult = df_mult.dropna(axis=1, how='all')
df_mult.head(10)
# Out:
# 3     COUNTY            PROJECT NAME    CYCLE             PROJECT ADDRESS
# 0  Multnomah   10th Avenue Townhomes    2000S   4916-38 NE 10th Ave; 4616   \
# 1  Multnomah      1200 Building, The    2011A                1220 SW 12th
# 2  Multnomah             124th & Ash   2018L3             12370 SE Ash St
# 3  Multnomah        12th Ave Terrace    1992P         1515-29 SW 12th Ave
# 4  Multnomah       146th East & West    2020A    14603 & 14525 E Burnside
# 5  Multnomah          148th Ave Apts   2021-2            208 SE 148th Ave
# 6  Multnomah                72Foster    2017A            5005 SE 72nd Ave
# 7  Multnomah      85 Stories Group 1    2014A      2140 NW Kearney/335 NW
# 8  Multnomah      85 Stories Group 2    2014A     4400 NE Broadway / 1724
# 9  Multnomah      85 Stories Group 5    2018A             Scattered Sites
#
# 3 PROJ CITY                              PROJ ZIP
# 0  Portland                                  97211  \
# ...

# %%
df_mult = df_mult.loc[:, ['COUNTY ', 'PROJECT NAME ', 'CYCLE ', 'PROJECT ADDRESS ', 'PROJ CITY ', 'PROJ ZIP ', 'APPLICANT/OWNER NAME ']]
df_mult
# Out:
# 3       COUNTY                            PROJECT NAME    CYCLE
# 0    Multnomah                   10th Avenue Townhomes    2000S   \
# 1    Multnomah                      1200 Building, The    2011A
# 2    Multnomah                             124th & Ash   2018L3
# 3    Multnomah                        12th Ave Terrace    1992P
# 4    Multnomah                       146th East & West    2020A
# ..          ...                                     ...      ...
# 709  Multnomah                Yards at Union Station C   4650916
# 710  Multnomah   Youth Psychatric Residential Facility         0
# 711  Multnomah                    Johnson Creek Duplex         0
# 712  Multnomah                  Los Jardines de la Paz   4195800
# 713  Multnomah                  Los Jardines de la Paz         0
#
# 3              PROJECT ADDRESS  PROJ CITY                     PROJ ZIP
# 0    4916-38 NE 10th Ave; 4616   Portland                         97211  \
# ...

# %%
df_mult = df_mult.fillna('')
# mask = df_mult['PROJECT ADDRESS '].str.contains(' W | NW ')
# df_west = df_mult.loc[mask]
# df_west
df_mult
# Out:
# 3       COUNTY                            PROJECT NAME    CYCLE
# 0    Multnomah                   10th Avenue Townhomes    2000S   \
# 1    Multnomah                      1200 Building, The    2011A
# 2    Multnomah                             124th & Ash   2018L3
# 3    Multnomah                        12th Ave Terrace    1992P
# 4    Multnomah                       146th East & West    2020A
# ..          ...                                     ...      ...
# 709  Multnomah                Yards at Union Station C   4650916
# 710  Multnomah   Youth Psychatric Residential Facility         0
# 711  Multnomah                    Johnson Creek Duplex         0
# 712  Multnomah                  Los Jardines de la Paz   4195800
# 713  Multnomah                  Los Jardines de la Paz         0
#
# 3              PROJECT ADDRESS  PROJ CITY                     PROJ ZIP
# 0    4916-38 NE 10th Ave; 4616   Portland                         97211  \
# ...
